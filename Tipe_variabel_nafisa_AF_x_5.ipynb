# %% [markdown]
# <a href="https://colab.research.google.com/github/nafisafajrin2025-spec/KKA-X-Semester-1/blob/main/Tipe_variabel_nafisa_AF_x_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama :Nafisa Aulia Fajrin
#
# kelas:x.5
#
# No.absen:27

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("nafisaauliafajrin2025")
print("nafisaauliafajrin2025")
print("nafisaauliafajrin2025")
# Out:
# nafisaauliafajrin2025
# nafisaauliafajrin2025
# nafisaauliafajrin2025

# %%
email_user_1="nafisaauliafajrin2025"


print=email_user_1
print=email_user_1
print=email_user_1

# %% [markdown]
# #Peraturan penulisan variabel

# %%
email_user_2="coklatkeju@gmail.com"

(email_user_2)
# Out:
# 'coklatkeju@gmail.com'

# %%
#Hanya boleh menggunakan angka , huruf dan underscore


email_user_2 ="coklatkeju@gmail.com"

print(email_user_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1446438274.py in <cell line: 0>()
#       4 email_user_2 ="coklatkeju@gmail.com"
#       5
# ----> 6 print(email_user_2)
#
# TypeError: 'str' object is not callable

# %%
3_email_user="wilisjaya@gmail.com"
(3_email_user)
# Out:
#   File "/tmp/ipython-input-4018516530.py", line 1
#     3_email_user="wilisjaya@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_2="wilisjaya@gmail.com"
print(email_user_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1262807264.py in <cell line: 0>()
#       1 email_user_2="wilisjaya@gmail.com"
# ----> 2 print(email_user_2)
#
# TypeError: 'str' object is not callable

# %%
#tidak boleh didahului angka
email_user_3="wilisjaya"

print(email_user_3)
# Out:
# wilisjaya

# %%
Email_user_4 = "nana@gmail.com"

print(email_user_4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-113715172.py in <cell line: 0>()
#       1 Email_user_4 = "nana@gmail.com"
#       2
# ----> 3 print(email_user_4)
#
# NameError: name 'email_user_4' is not defined

# %%
#penulisan variabel sensitif terhadap kapital

Email_user_4 = "nana@gmail.com"

print (Email_user_4)
# Out:
# nana@gmail.com

# %%
if = "niken@gmail.com"

print(if)
# Out:
#   File "/tmp/ipython-input-841533039.py", line 1
#     if = "niken@gmail.com"
#        ^
# SyntaxError: invalid syntax

# %%
If ="niken@gmail.com"

print (If)
# Out:
# niken@gmail.com

# %%
print ="larasati@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3092999876.py in <cell line: 0>()
#       1 print ="larasati@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
print ="larasati@gmail.com"

print(Print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-476393645.py in <cell line: 0>()
#       1 print ="larasati@gmail.com"
#       2
# ----> 3 print(Print)
#
# TypeError: 'str' object is not callable

# %%
#Harus deskripsi meskipun tidak eror
_ ="ana@gmail.com"

print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3630398810.py in <cell line: 0>()
#       2 _="ana@gmail.com"
#       3
# ----> 4 print(_)
#
# TypeError: 'str' object is not callable

# %%
_="mega@gmail.com"

print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1328343382.py in <cell line: 0>()
#       1 _="mega@gmail.com"
#       2
# ----> 3 print(_)
#
# TypeError: 'str' object is not callable

# %%
print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3119395983.py in <cell line: 0>()
# ----> 1 print(_)
#
# TypeError: 'str' object is not callable

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3925571382.py in <cell line: 0>()
# ----> 1 print(i)
#
# NameError: name 'i' is not defined

# %% [markdown]
# #Jenis-jenis operator aritmatika pada pyhton

# %%
 #Penjumlahan
iphone_rolan = 21
iphone_gibran = 4

total_iphone = iphone_rolan + iphone_gibran

print(total_iphone)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1388417920.py in <cell line: 0>()
#       5 total_iphone = iphone_rolan + iphone_gibran
#       6
# ----> 7 print(total_iphone)
#
# TypeError: 'str' object is not callable

# %%
#Pengurangan
iphone_rolan = 21
iphone_gibran = 4

selisih_iphone = iphone_rolan - iphone_gibran

print(selisih_iphone)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3918429843.py in <cell line: 0>()
#       5 selisih_iphone = iphone_rolan - iphone_gibran
#       6
# ----> 7 print(selisih_iphone)
#
# TypeError: 'str' object is not callable

# %%
#perkalian
jumlah_dus = 5
jumlah_botol_per_dus = 10

total_botol = jumlah_dus * jumlah_botol_per_dus

print(total_botol)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2050455029.py in <cell line: 0>()
#       5 total_botol = jumlah_dus * jumlah_botol_per_dus
#       6
# ----> 7 print(total_botol)
#
# TypeError: 'str' object is not callable

# %%
#Pembagian
iphone_rolan = 21
jumlah_anak_yatim = 5

pembagian_iphone = iphone_rolan / iphone_gibran

print(pembagian_iphone)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4068814666.py in <cell line: 0>()
#       5 pembagian_iphone = iphone_rolan / iphone_gibran
#       6
# ----> 7 print(pembagian_iphone)
#
# TypeError: 'str' object is not callable

# %%
#Pembagian bulat
iphone_rolan = 21
jumlah_anak_yatim = 5

pembagian_iphone = iphone_rolan // iphone_gibran

print(pembagian_iphone)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-923157286.py in <cell line: 0>()
#       5 pembagian_iphone = iphone_rolan // iphone_gibran
#       6
# ----> 7 print(pembagian_iphone)
#
# TypeError: 'str' object is not callable

# %%
#sisa bagi

iphone_rolan = 21
jumlah_anak_yatim = 5

sisa_bagi_iphone = iphone_rolan % jumlah_anak_yatim

print(sisa_bagi_iphone)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2564811817.py in <cell line: 0>()
#       6 sisa_bagi_iphone = iphone_rolan % jumlah_anak_yatim
#       7
# ----> 8 print(sisa_bagi_iphone)
#
# TypeError: 'str' object is not callable

# %%
#perpangkatan
sisi = 5

luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2951001445.py in <cell line: 0>()
#       4 luas_persegi = sisi ** 2
#       5
# ----> 6 print(luas_persegi)
#
# TypeError: 'str' object is not callable

# %%
#perpangkatan
sisi = 5

luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2951001445.py in <cell line: 0>()
#       4 luas_persegi = sisi ** 2
#       5
# ----> 6 print(luas_persegi)
#
# TypeError: 'str' object is not callable

# %%
sisi = 2
volume_kubus = sisi ** 3

print(volume_kubus)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3991546147.py in <cell line: 0>()
#       2 volume_kubus = sisi ** 3
#       3
# ----> 4 print(volume_kubus)
#
# TypeError: 'str' object is not callable

# %%
luas_persegi = 25

sisi = luas_persegi ** (1/2)

print(sisi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2561005234.py in <cell line: 0>()
#       3 sisi = luas_persegi ** (1/2)
#       4
# ----> 5 print(sisi)
#
# TypeError: 'str' object is not callable

# %%
volume_kubus = 8
sisi = volume_kubus ** (1/3)

print(sisi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3267032217.py in <cell line: 0>()
#       2 sisi = volume_kubus ** (1/3)
#       3
# ----> 4 print(sisi)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Jenis Tipe Variabel pada Python

# %%
#Float
x = 17.5
print(x)
type(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1298060847.py in <cell line: 0>()
#       1 #Float
#       2 x = 17.5
# ----> 3 print(x)
#       4 type(x)
#
# TypeError: 'str' object is not callable

# %%
#Integer
y = 8
print(y)
type(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1004582950.py in <cell line: 0>()
#       1 #Integer
#       2 y = 8
# ----> 3 print(y)
#       4 type(y)
#
# TypeError: 'str' object is not callable

# %%
#String
z = "shinta"
print(z)
type(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-307649854.py in <cell line: 0>()
#       1 #String
#       2 z = "shinta"
# ----> 3 print(z)
#       4 type(z)
#
# TypeError: 'str' object is not callable

# %%
#Boolean
p = True
print(p)
type(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1037090062.py in <cell line: 0>()
#       1 #Boolean
#       2 p = True
# ----> 3 print(p)
#       4 type(p)
#
# TypeError: 'str' object is not callable

# %%
r = -2.5
print(r)
type(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-490536173.py in <cell line: 0>()
#       1 r = -2.5
# ----> 2 print(r)
#       3 type(r)
#
# TypeError: 'str' object is not callable

# %%
s = 5.1
print(s)
type(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1904761672.py in <cell line: 0>()
#       1 s = 5.1
# ----> 2 print(s)
#       3 type(s)
#
# TypeError: 'str' object is not callable

# %%
k = '%7akh3.'
print(k)
type(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3146244300.py in <cell line: 0>()
#       1 k = '%7akh3.'
# ----> 2 print(k)
#       3 type(k)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #mengubah tipe data

# %%
a = 25
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1784430839.py in <cell line: 0>()
#       1 a = 25
# ----> 2 print(a)
#       3 type(a)
#
# TypeError: 'str' object is not callable

# %%
a = float(a)
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3962232315.py in <cell line: 0>()
#       1 a = float(a)
# ----> 2 print(a)
#       3 type(a)
#
# TypeError: 'str' object is not callable

# %%
a = str(a)
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3821863648.py in <cell line: 0>()
#       1 a = str(a)
# ----> 2 print(a)
#       3 type(a)
#
# TypeError: 'str' object is not callable

# %%
a = bool(a)
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-161547671.py in <cell line: 0>()
#       1 a = bool(a)
# ----> 2 print(a)
#       3 type(a)
#
# TypeError: 'str' object is not callable

# %%
b = True
print(b)
type(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1340759451.py in <cell line: 0>()
#       1 b = True
# ----> 2 print(b)
#       3 type(b)
#
# TypeError: 'str' object is not callable

# %%
b = int(b)
print(b)
type(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-903555575.py in <cell line: 0>()
#       1 b = int(b)
# ----> 2 print(b)
#       3 type(b)
#
# TypeError: 'str' object is not callable

# %%
b = float(b)
print(b)
type(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2688239477.py in <cell line: 0>()
#       1 b = float(b)
# ----> 2 print(b)
#       3 type(b)
#
# TypeError: 'str' object is not callable

# %%
b = str(b)
print(b)
type(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2594274079.py in <cell line: 0>()
#       1 b = str(b)
# ----> 2 print(b)
#       3 type(b)
#
# TypeError: 'str' object is not callable

# %%
c = False
print(c)
type(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-778869892.py in <cell line: 0>()
#       1 c = False
# ----> 2 print(c)
#       3 type(c)
#
# TypeError: 'str' object is not callable

# %%
c = float(c)
print(c)
type(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3168067449.py in <cell line: 0>()
#       1 c = float(c)
# ----> 2 print(c)
#       3 type(c)
#
# TypeError: 'str' object is not callable

# %%
c = int(c)
print(c)
type(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4221954543.py in <cell line: 0>()
#       1 c = int(c)
# ----> 2 print(c)
#       3 type(c)
#
# TypeError: 'str' object is not callable

# %%
c = str(c)
print(c)
type(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-698934447.py in <cell line: 0>()
#       1 c = str(c)
# ----> 2 print(c)
#       3 type(c)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #operator perbandingan

# %%
print(6>0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-169882221.py in <cell line: 0>()
# ----> 1 print(6>0)
#
# TypeError: 'str' object is not callable

# %%
print(7>9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-482533824.py in <cell line: 0>()
# ----> 1 print(7>9)
#
# TypeError: 'str' object is not callable

# %%
print(8<9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2581981622.py in <cell line: 0>()
# ----> 1 print(8<9)
#
# TypeError: 'str' object is not callable

# %%
print(8<4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1017596466.py in <cell line: 0>()
# ----> 1 print(8<4)
#
# TypeError: 'str' object is not callable

# %%
print(5>=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-118839835.py in <cell line: 0>()
# ----> 1 print(5>=5)
#
# TypeError: 'str' object is not callable

# %%
print(6>=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3462995542.py in <cell line: 0>()
# ----> 1 print(6>=5)
#
# TypeError: 'str' object is not callable

# %%
print(3 == 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2440364767.py in <cell line: 0>()
# ----> 1 print(3 == 2)
#
# TypeError: 'str' object is not callable

# %%
print(3 == 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3903499788.py in <cell line: 0>()
# ----> 1 print(3 == 3)
#
# TypeError: 'str' object is not callable

# %%
print(5 != 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3724328804.py in <cell line: 0>()
# ----> 1 print(5 != 5)
#
# TypeError: 'str' object is not callable

# %%
a = 8
b = 9
print(b<a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3056785611.py in <cell line: 0>()
#       1 a = 8
#       2 b = 9
# ----> 3 print(b<a)
#
# TypeError: 'str' object is not callable

# %%
print(b<8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1027953185.py in <cell line: 0>()
# ----> 1 print(b<8)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# #operator logika

# %%
print(7!=8 and 8>2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3905736858.py in <cell line: 0>()
# ----> 1 print(7!=8 and 8>2)
#
# TypeError: 'str' object is not callable

# %%
ohprint(7==8 and 8>2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3800533520.py in <cell line: 0>()
# ----> 1 print(7==8 and 8>2)
#
# TypeError: 'str' object is not callable

# %%
print(7==8 or 8>2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3468069991.py in <cell line: 0>()
# ----> 1 print(7==8 or 8>2)
#
# TypeError: 'str' object is not callable

# %%
print(not 7==8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2769333239.py in <cell line: 0>()
# ----> 1 print(not 7==8)
#
# TypeError: 'str' object is not callable

# %%
m = 10
n = 20
p = 30

print(m<n and p>m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2902986145.py in <cell line: 0>()
#       3 p = 30
#       4
# ----> 5 print(m<n and p>m)
#
# TypeError: 'str' object is not callable

# %%
print(not (m<n or p>m))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1405939521.py in <cell line: 0>()
# ----> 1 print(not (m<n or p>m))
#
# NameError: name 'm' is not defined
