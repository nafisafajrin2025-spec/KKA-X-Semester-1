# %% [markdown]
# <a href="https://colab.research.google.com/github/nafisafajrin2025-spec/KKA-X-Semester-1/blob/main/fungsi_print_nafisa_a_f_x_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.menampilkan teks bebas

# %%
print("hello word")
# Out:
# hello word

# %%
print("nafisa aulia fajrin")
# Out:
# nafisa aulia fajrin

# %% [markdown]
# #2.menampilkan nilai variabel

# %%
namaidola = "chatezz"
print("namaidola")
# Out:
# namaidola

# %%
Nama ="Nafisa aulia fajrin"

# %%
beratbadan = 43
print(beratbadan)
# Out:
# 43

# %% [markdown]
# #3.menampilkan teks bebas dan nilai variabel

# %%
print("Halo nama Saya", Nama,". Berat badan Saya", beratbadan, "kg.")
# Out:
# Halo nama Saya Nafisa aulia fajrin . Berat badan Saya 43 kg.

# %%
print("Halo nama Saya "+ Nama+". Berat badan Saya "+str(beratbadan)+" kg.")
# Out:
# Halo nama Saya Nafisa aulia fajrin. Berat badan Saya 43 kg.

# %%
print(f"Halo nama Saya {Nama}. Berat badan Saya {beratbadan} kg.")
# Out:
# Halo nama Saya Nafisa aulia fajrin. Berat badan Saya 43 kg.

# %% [markdown]
# #4. Escape Character

# %%
print("Nama: Nafisa aulia fajrin")
print("Kelas: X-5")
print("No. Absen: 27")
# Out:
# Nama: Nafisa aulia fajrin
# Kelas: X-5
# No. Absen: 27

# %%
print("Nama: Nafisa aulia fajrin\nKelas: X-5\nNo. Absen: 27")
# Out:
# Nama: Nafisa aulia fajrin
# Kelas: X-5
# No. Absen: 27

# %%
print("""Nama\t\t: Nafisa aulia fajrin
Kelas\t\t: X-5
No. Absen\t: 27""")
# Out:
# Nama		: Nafisa aulia fajrin
# Kelas		: X-5
# No. Absen	: 27

# %%
print('Nama Saya Ja\'far Shodiq')
# Out:
# Nama Saya Ja'far Shodiq

# %%
print("Nama Saya Ja'far Shodiq")
# Out:
# Nama Saya Ja'far Shodiq

# %%
print('Bu Shinta berkata, "Tolong perhatikan TV dan Saya."')
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %%
print('Bu Shinta berkata, "Tolong perhatikan TV dan Saya."')
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %%
print("Bu Shinta berkata, \"Tolong perhatikan TV dan Saya.\"")
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %%
print("Lokasi file tugas KKA adalah di Local Disk C:\\KKA\\Tugas")
# Out:
# Lokasi file tugas KKA adalah di Local Disk C:\KKA\Tugas

# %% [markdown]
# #parameter fungsi print

# %%
nama_siswa_1 = "Jielo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"
nama_siswa_4 = "Nurul"

print(nama_siswa_1, end="/")
print(nama_siswa_2, end="/")
print(nama_siswa_3, end="/")
print(nama_siswa_4)
# Out:
# Jielo/Aida/Dani/Nurul

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_6, nama_siswa_5, sep="*")
# Out:
# Naufal*Rendra*Habibi*Hasbi

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_5, nama_siswa_6, sep="-")
# Out:
# Naufal-Rendra-Hasbi-Habibi
