# %% [markdown]
# <a href="https://colab.research.google.com/github/nafisafajrin2025-spec/KKA-X-Semester-1/blob/main/app_bangun_balok_nafisaa_f_x_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama Kelompok: Ayam Terbang
# Nama Panjang: Nafisa Aulia Fajrin
# Kelas : X.5
# No.Absen : 27

# %% [markdown]
# App Bangun Balok

# %%
# Progam menghitung volume balok

#Meminta input dari pengguna
panjang = float(input("masukan panjang volume balok(cm):"))
lebar = float(input("masukan lebar volume balok(cm):"))
tinggi = float(input("masukan tinggi volume balok(cm):"))

#Menghitung volume
volume = panjang * lebar * tinggi

#Menampilkan hasil
print( f"volume balok adalah:{volume} cm^3.")
# Out:
# masukan panjang volume balok(cm):5
# masukan lebar volume balok(cm):3
# masukan tinggi volume balok(cm):3
# volume balok adalah:45.0 cm^3.
